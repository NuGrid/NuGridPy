# %%
# %matplotlib ipympl 
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pyplot import close, figure, plot
from numpy import sin
import sys
sys.path.insert(0, "/Users/fherwig/Nextcloud/NextRepos/NuGrid/NuGridPy")
from nugridpy import utils as ut
x=np.linspace(0,6,500)
close(1);    figure(1,figsize=(9,6))
for i in range(1,4):
    ci=str(i).zfill(4)
    ls=ut.linestylecb(i,20,7)
    plot(x,sin(i*x), color=ls[2], linestyle=ls[0],marker=ls[1],markevery=int(ls[3]))
plt.xlabel("x")
plt.ylabel("sin(i*x)")
plt.legend(['i=1', 'i=2', 'i=3'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ut.linestylecb(2)
# Out:
# ('-.', '<', (0.6705882352941176, 0.6705882352941176, 0.6705882352941176), 7)

# %%
i=5
ci=str(i).zfill(4)

# %%
abs(int(10*sin(50)))
# Out:
# 2

# %%
ci.zfill(5)
# Out:
# '00003'

# %%
i=10
close(1),figure(1)
x=np.linspace(0,6,50)
plot(x,sin(x))
plt.xlabel("x")
plt.ylabel("$ \\rho \\times \\mu \\times \\pi$")
plt.title("Hello World!")
plt.savefig('sin'+ci+'.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
